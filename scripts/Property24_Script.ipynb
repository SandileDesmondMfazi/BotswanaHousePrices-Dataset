# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
def count_digits(n):
    return len(str(n))

# bs.find_all(class_= re.compile('UnfussyTexan'))
def has_six_characters(css_class):
    n = 114760940
    length = count_digits(n)
    return css_class is not None and len(css_class) == length

# %%
c = 0
Dataset = []
for page in range(1, 24, 1): 
    url = f'https://www.property24.co.bw/property-for-sale-in-gaborone-c2250?Page={page}'
    response = requests.get(url)
    html = response.text
    bs = BeautifulSoup(html, 'html.parser') 

    for Listing in bs.find_all(attrs={"data-listing-number": has_six_characters}): 
        c += 1
        Agency = "Property24"
        title = Listing.find('span', class_='p24_propertyTitle').get_text(strip=True)
        # FeaturesDetails = Listing.find('span', class_='p24_featureDetails')
        bedrooms_count = Listing.find(attrs={'title': 'Bedrooms'})
        if bedrooms_count:
            bedrooms = bedrooms_count.get_text(strip=True)
        else:
            bedrooms = None 
        bathrooms_count = Listing.find(attrs={'title': 'Bathrooms'})
        if bathrooms_count:
            bathrooms = bathrooms_count.get_text(strip=True)
        else:
            bathrooms = None 
        parking_count = Listing.find(attrs={'title': 'Bathrooms'})
        if parking_count:
            parking_spaces = parking_count.get_text(strip=True)
        else:
            parking_spaces = None

        P_Size_count = Listing.find(attrs={'title': 'Erf Size'})
        if P_Size_count:
            property_size = P_Size_count.get_text(strip=True)
        else:
            property_size = None 

        location = Listing.find('span',{'class':'p24_location'}).get_text(strip=True)
        descrip = Listing.find('span',{'class':'p24_excerpt'}).get_text(strip=True)
        link = f"https://www.property24.co.bw{Listing.find('a')['href']}"
        price = Listing.find('span',{'class':'p24_price'}).get_text(strip=True) 

        Data = {
            'Title': title,
            'Location': location,
            'Description':descrip,
            'Link':link,
            'Bedrooms': bedrooms,
            'Bathrooms': bathrooms,
            'Parking Spaces': parking_spaces,
            'Erf Size': property_size,
            'Agency':Agency,
            'Price': price
        }
        Dataset.append(Data)

Dataset_Part1 = pd.DataFrame(Dataset)
print(len(Dataset_Part1))
# Out:
# 966

# %%
Dataset_Part1.sort_values(by='Bedrooms', ascending=False).head(30)
# Out:
#                           Title          Location  \
# 782             9 Bedroom House        Broadhurst
# 843             9 Bedroom House          Gaborone
# 842             9 Bedroom House          Gaborone
# 931             9 Bedroom House          Gaborone
# 930             9 Bedroom House          Gaborone
# 783             9 Bedroom House        Broadhurst
# 810             8 Bedroom House          Gaborone
# 811             8 Bedroom House          Gaborone
# 557             8 Bedroom House        Mokolodi 1
# 556             8 Bedroom House        Mokolodi 1
# 218  8 Bedroom Apartment / Flat           Block 6
# 219  8 Bedroom Apartment / Flat           Block 6
# 651             6 Bedroom House        Mokolodi 1
# 125             6 Bedroom House           Village
# 124             6 Bedroom House           Village
# 608             6 Bedroom House          Block 10
# 146             6 Bedroom House  Gaborone Central
# 147             6 Bedroom House  Gaborone Central
# ...

# %%
Dataset_Part1.to_csv('../data/New_Property24.csv', encoding='utf-8', index = True)
